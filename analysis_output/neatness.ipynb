# %%
import pandas as pd

# %%
loadings_df = pd.read_csv("pc5_loadings.csv", index_col=0)
loadings_df.round(2).to_latex()
# Out:
# '\\begin{tabular}{lrrrrr}\n\\toprule\n & PC1 & PC2 & PC3 & PC4 & PC5 \\\\\n\\midrule\nVIX & -0.180000 & 0.540000 & -0.240000 & 0.450000 & 0.380000 \\\\\n2Y & 0.460000 & 0.280000 & 0.140000 & 0.010000 & 0.050000 \\\\\n10Y & 0.370000 & 0.340000 & 0.430000 & -0.020000 & 0.070000 \\\\\nYieldCurve & -0.350000 & 0.030000 & 0.570000 & -0.060000 & 0.020000 \\\\\nCreditSpread & -0.400000 & 0.300000 & -0.120000 & 0.200000 & 0.190000 \\\\\nFedFundsRate & 0.460000 & 0.270000 & 0.030000 & 0.030000 & 0.050000 \\\\\nInflation_YoY & 0.140000 & -0.340000 & 0.210000 & 0.870000 & -0.250000 \\\\\nUnemploymentRate & -0.310000 & 0.180000 & 0.570000 & -0.020000 & -0.060000 \\\\\nGDP_YoY & 0.110000 & -0.450000 & 0.180000 & 0.010000 & 0.860000 \\\\\n\\bottomrule\n\\end{tabular}\n'
