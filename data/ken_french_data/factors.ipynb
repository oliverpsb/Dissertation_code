# %%
import pandas as pd
import zipfile
import os

# %% [markdown]
# Download the fama/french 5 daily csv

# %%
fama_french_5 = pd.read_csv('F-F_Research_Data_5_Factors_2x3_daily_CSV.zip', compression = 'zip', skiprows=2) # Read CSV skipping out the rows that contain headers/notes
fama_french_5.rename(columns={fama_french_5.columns[0]: "Date"}, inplace = True) # Rename first column to date
fama_french_5['Date'] = pd.to_datetime(fama_french_5['Date'], format= '%Y%m%d') # Fix datetime format to YYYY - MM - DD

fama_french_5.head()
# Out:
#         Date  Mkt-RF   SMB   HML   RMW   CMA     RF
# 0 1963-07-01   -0.67  0.02 -0.35  0.03  0.13  0.012
# 1 1963-07-02    0.79 -0.28  0.28 -0.08 -0.21  0.012
# 2 1963-07-03    0.63 -0.18 -0.10  0.13 -0.25  0.012
# 3 1963-07-05    0.40  0.09 -0.28  0.07 -0.30  0.012
# 4 1963-07-08   -0.63  0.07 -0.20 -0.27  0.06  0.012

# %% [markdown]
# Working with fama-french data from kenneth data library means that I am only working with US equities
#
# Mkt - RF = market excess return = return on the market portfolio minus the risk free rate
# SMB = Small minus big = size factor: return of small cap stocks minus large cap stocks
# HML = high minus low = value factor: return of high book-to-market (value) stocks minus low book-to-market (growth) stocks
# RMW = robust minus weak = profitability factor: return of firms with robust (high) operating profitability minus those with weak profitability
# CMA = Conservative minus aggressive = investment factor: return of firms that invest in conservatively (low asset growth) minus those that invest aggressively (high asset growth)
# RF = risk-free rate = monthly return on a risk free asset

# %%
os.getcwd()
# Out:
# 'c:\\Users\\User\\Documents\\Big Data and Digital Futures\\Dissertation\\Dissertation_code\\data\\ken_french_data'

# %%
momentum = pd.read_csv('F-F_Momentum_Factor_CSV.zip', compression = 'zip', skiprows=2)
momentum.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 momentum = pd.read_csv('F-F_Momentum_Factor_CSV.zip', compression = 'zip', skiprows=2)
#       2 momentum.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\common.py:794, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     789 # ZIP Compression
#     790 elif compression == "zip":
#     791     # error: Argument 1 to "_BytesZipFile" has incompatible type
#     792     # "Union[str, BaseBuffer]"; expected "Union[Union[str, PathLike[str]],
#     793     # ReadBuffer[bytes], WriteBuffer[bytes]]"
# --> 794     handle = _BytesZipFile(
#     795         handle, ioargs.mode, **compression_args  # type: ignore[arg-type]
#     796     )
#     797     if handle.buffer.mode == "r":
#     798         handles.append(handle)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\common.py:1037, in _BytesZipFile.__init__(self, file, mode, archive_name, **kwargs)
#    1034 kwargs.setdefault("compression", zipfile.ZIP_DEFLATED)
#    1035 # error: Incompatible types in assignment (expression has type "ZipFile",
#    1036 # base class "_BufferedWriter" defined the type as "BytesIO")
# -> 1037 self.buffer: zipfile.ZipFile = zipfile.ZipFile(  # type: ignore[assignment]
#    1038     file, mode, **kwargs
#    1039 )
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\zipfile\__init__.py:1336, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1334 while True:
#    1335     try:
# -> 1336         self.fp = io.open(file, filemode)
#    1337     except OSError:
#    1338         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'F-F_Momentum_Factor_CSV.zip'
